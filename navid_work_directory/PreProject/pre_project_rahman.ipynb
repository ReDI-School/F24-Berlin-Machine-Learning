# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("train_labeled.csv", delimiter=';')
df2 = pd.read_csv("prediction_unlabeled.csv", delimiter=';')

# %%
df2.head()
# Out:
#    ID    Maker          Genmodel  Genmodel_ID  Adv_year  Adv_month  Color  \
# 0   1  Citroen  Grand C4 Picasso        18_24      2018          6  Black
# 1   2  Citroen        C3 Picasso        18_10      2017          8   Blue
# 2   3     Fiat             Doblo        28_12      2018          4   Grey
# 3   4     Ford             B-Max         29_1      2018          3  Black
# 4   5    Honda              CR-V         34_3      2018          2   Blue
#
#    Reg_year Bodytype  Runned_Miles  ... Door_num             issue issue_id  \
# 0    2008.0      MPV         98121  ...      5.0      Engine Issue        1
# 1    2011.0      MPV         29000  ...      5.0  Electrical Issue        2
# 2    2003.0   Estate        142321  ...      5.0  Electrical Issue        2
# 3    2017.0      MPV           320  ...      5.0  Electrical Issue        3
# 4    2002.0      SUV        161000  ...      5.0        Flat Tyres        0
#
# ...

# %%
df1.head()
# Out:
#       ID  Maker  Genmodel  Genmodel_ID  Adv_year  Adv_month   Color  Reg_year  \
# 0  16130   Ford       Ka+        29_24      2018          4    Blue    2017.0
# 1  16131   Ford      Edge         29_5      2018          5    Blue    2016.0
# 2  16132  Honda      CR-V         34_3      2018          8    Grey    2012.0
# 3  16133   Ford      Kuga        29_25      2018          5  Silver    2012.0
# 4  16134  Honda      CR-V         34_3      2018          6    Grey    2018.0
#
#     Bodytype  Runned_Miles  ...                     issue issue_id Adv_day  \
# 0  Hatchback          1636  ...            Tyre Alignment        0      15
# 1        SUV          9820  ...          Radiator Leaking        0      20
# 2        SUV         38500  ...        Sensor Malfunction        0      26
# 3        SUV         43445  ...            Gear Box Issue        0       6
# 4        SUV          7491  ...     Alternator Failing           0       5
#
# ...

# %%
df1 = df1.drop([' Genmodel', 'Color'], axis = 1, index=None)

# %%
df1.head()
# Out:
#       ID  Genmodel_ID  Adv_year  Adv_month  Reg_year   Bodytype  Runned_Miles  \
# 0  16130        29_24      2018          4    2017.0  Hatchback          1636
# 1  16131         29_5      2018          5    2016.0        SUV          9820
# 2  16132         34_3      2018          8    2012.0        SUV         38500
# 3  16133        29_25      2018          5    2012.0        SUV         43445
# 4  16134         34_3      2018          6    2018.0        SUV          7491
#
#   Engin_size    Gearbox Fuel_type  ...                     issue  issue_id  \
# 0       1.2L     Manual    Petrol  ...            Tyre Alignment         0
# 1       2.0L     Manual    Diesel  ...          Radiator Leaking         0
# 2       2.2L  Automatic    Diesel  ...        Sensor Malfunction         0
# 3       2.0L     Manual    Diesel  ...            Gear Box Issue         0
# 4       1.6L     Manual    Diesel  ...     Alternator Failing            0
#
# ...

# %%
df2 = df2.drop(['Maker', ' Genmodel', 'Color'], axis = 1, index=None)

# %%
df2.head()
# Out:
#    ID  Genmodel_ID  Adv_year  Adv_month  Reg_year Bodytype  Runned_Miles  \
# 0   1        18_24      2018          6    2008.0      MPV         98121
# 1   2        18_10      2017          8    2011.0      MPV         29000
# 2   3        28_12      2018          4    2003.0   Estate        142321
# 3   4         29_1      2018          3    2017.0      MPV           320
# 4   5         34_3      2018          2    2002.0      SUV        161000
#
#   Engin_size    Gearbox Fuel_type  ...  Door_num             issue  issue_id  \
# 0       2.0L  Automatic    Diesel  ...       5.0      Engine Issue         1
# 1       1.6L     Manual    Petrol  ...       5.0  Electrical Issue         2
# 2       1.9L     Manual    Diesel  ...       5.0  Electrical Issue         2
# 3       1.0L     Manual    Petrol  ...       5.0  Electrical Issue         3
# 4       2.0L     Manual    Petrol  ...       5.0        Flat Tyres         0
#
# ...
