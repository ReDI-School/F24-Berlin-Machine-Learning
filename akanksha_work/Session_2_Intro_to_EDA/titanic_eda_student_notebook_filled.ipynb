# %% [markdown]
# # Titanic Dataset: Exploratory Data Analysis (EDA)
#
# Welcome to the Titanic dataset EDA notebook! In this notebook, you will explore the Titanic dataset, clean the data, and perform some basic visualizations. Follow the instructions in each cell and complete the tasks where needed.
#
# Let's get started!

# %%
# Task: Import the necessary libraries for data analysis and visualization
# Libraries to import: pandas, numpy, matplotlib, seaborn


#!pip install pandas numpy  matplotlib seaborn
#!conda install 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Use %matplotlib inline if you are using Jupyter Notebook for inline plotting

# %%
# Task: Load the Titanic dataset into a pandas DataFrame
# You can use 'titanic.csv' if the dataset is available locally or provide a URL to load it.

# Example: df = pd.read_csv('titanic.csv')

# Load your dataset here
df = pd.read_csv('titanic.csv')

# Preview the first few rows of the dataset using df.head()
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ##Variable	##Definition	##Key
#
# Survived	Survival	0 = No, 1 = Yes
#
# Pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
#
# Sex	Sex
#
# Age	Age in years
#
# Sibsp	# of siblings / spouses aboard the Titanic
#
# Parch	# of parents / children aboard the Titanic
#
# Ticket	Ticket number
#
# Fare	Passenger fare
#
# Cabin	Cabin number
#
# Embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown,S = Southampton

# %%
# Task: Inspect the dataset to understand its structure
# Instructions: Use df.info() to check the data types and non-null values for each column.
df.info()
# Add df.describe() to get a summary of the numerical features.
df.describe()
# Inspect data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Task: Check for missing data in the dataset
# Instructions: Use isnull().sum() to count missing values per column.
# Explore how to handle missing values (fillna or dropna).

# Example:
df.isnull().sum()

# Now handle missing values by either dropping or filling them
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1=df

# %%
df['Age'] = df['Age'].fillna(30)

#rounded mean age, Is this a good idea? 
#It might be better to have a look at the parents or siblings column and use that in our analysis.

# %%
# Now would be a good time to run df.describe again and see if this has warped our data
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.758889    0.523008
# std     257.353842    0.486592    0.836071   13.002570    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   30.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# if we compare the new mean to the old we can see its increased from 29.699118 to 29.758889

# %%
# Task: Perform additional data cleaning steps if needed
# Instructions: Look for duplicates, adjust data types, and rename columns where necessary.

# Remove duplicate rows, if any
#df.drop_duplicates(inplace=True)

# Check if any columns need renaming or converting to appropriate data types
# Example: df['column_name'] = df['column_name'].astype('new_dtype')
df = df.rename(columns={'Sex': 'Gender'})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Task: Generate descriptive statistics for the dataset
# Instructions: Use df.describe() to get an overview of the numerical columns.
# Use value_counts() for categorical columns to see the distribution of values.

# Example:
#df.describe()

# Now calculate statistics for specific columns (e.g., mean, median)
df['Age'].mean(), df['Pclass'].value_counts()
# Out:
# (29.758888888888887,
#  Pclass
#  3    491
#  1    216
#  2    184
#  Name: count, dtype: int64)

# %%
# Task: Create visualizations to explore the data
# Instructions: Create a bar chart or a histogram to visualize the distribution of certain features.

# Example: Use matplotlib or seaborn to plot the distribution of 'Age' or 'Fare'
sns.scatterplot(df, x='Age',y='Fare')


# Now create a bar chart for categorical data such as 'Pclass' or 'Sex'
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.displot(
df, x="Age", col="Survived", row="Gender",
binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
sns.barplot(x=df['Gender'], y=df['Survived'])
# Out:
# <Axes: xlabel='Gender', ylabel='Survived'>

# %% [markdown]
# Now we need to have a look at what data is going to be useful going forward for our analysis, something like name doesnt really matter too much so we can drop it. Wh else could we drop? We will also need to look at converting our categorical data into numerical. In the coming lessons we will show you about using OneHotEncoding and get dummies which create a column for each available option in a column, for example it would split gender into 2 columns, male and female and assign a 1 or 0 to this, in fact we only need one column for this, we can just have 1 or 0 for either male or female because the alternative is the other.

# %%
df1= df.drop(['Name'], axis=1)
df1['Gender'] = df1['Gender'].map({'male': 0, 'female': 1})

df1.head()
# Out:
#    PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 0            1         0       3       0  22.0      1      0
# 1            2         1       1       1  38.0      1      0
# 2            3         1       3       1  26.0      0      0
# 3            4         1       1       1  35.0      1      0
# 4            5         0       3       0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# Lets also convert the age to an int64

# %%
df1['Age'] = df['Age'].astype('int64')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Gender  Age  SibSp  Parch            Ticket  \
# 0            1         0       3       0   22      1      0         A/5 21171
# 1            2         1       1       1   38      1      0          PC 17599
# 2            3         1       3       1   26      0      0  STON/O2. 3101282
# 3            4         1       1       1   35      1      0            113803
# 4            5         0       3       0   35      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %% [markdown]
# Lets drop the Ticket and Cabin number for now, currently it doesnt seem useful, you can always add it back later

# %%
df1= df1.drop(['Ticket', 'Cabin'], axis=1)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Gender  Age  SibSp  Parch     Fare Embarked
# 0            1         0       3       0   22      1      0   7.2500        S
# 1            2         1       1       1   38      1      0  71.2833        C
# 2            3         1       3       1   26      0      0   7.9250        S
# 3            4         1       1       1   35      1      0  53.1000        S
# 4            5         0       3       0   35      0      0   8.0500        S

# %% [markdown]
# we still have the Emarked feature so lets map that to 1,2,3 just like we did with the gender and lets make it more easy to understand

# %%
df1['Embarked_from'] = df1['Embarked'].map({'C': 0, 'Q': 1, 'S':2})
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Gender  Age  SibSp  Parch     Fare Embarked  \
# 0            1         0       3       0   22      1      0   7.2500        S
# 1            2         1       1       1   38      1      0  71.2833        C
# 2            3         1       3       1   26      0      0   7.9250        S
# 3            4         1       1       1   35      1      0  53.1000        S
# 4            5         0       3       0   35      0      0   8.0500        S
#
#    Embarked_from
# 0            2.0
# 1            0.0
# 2            2.0
# 3            2.0
# 4            2.0

# %% [markdown]
# now we also need to drop or old embarked column

# %%
df1= df1.drop(['Embarked'], axis=1)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Gender  Age  SibSp  Parch     Fare  \
# 0            1         0       3       0   22      1      0   7.2500
# 1            2         1       1       1   38      1      0  71.2833
# 2            3         1       3       1   26      0      0   7.9250
# 3            4         1       1       1   35      1      0  53.1000
# 4            5         0       3       0   35      0      0   8.0500
#
#    Embarked_from
# 0            2.0
# 1            0.0
# 2            2.0
# 3            2.0
# 4            2.0

# %%
# Task: Explore relationships between variables
# Instructions: Create a correlation matrix to see how features are related to each other.
# Use a heatmap from seaborn to visualize the correlations.

sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Task: Explore further! 
# Instructions: Feel free to explore other relationships in the data using scatter plots or other visualizations.

# For example, plot 'Fare' vs 'Age' to see if there's any trend:
plt.scatter(df1['Age'], df1['Fare'])

# Try exploring any other interesting relationships in the dataset.

# %% [markdown]
# # Task: Summarize your findings
# Now that you’ve completed the EDA, take a moment to reflect on the key insights you gathered from the Titanic dataset. What interesting patterns did you observe? Are there any obvious outliers or trends?
#
# Feel free to add your conclusions here.

# %% [markdown]
# As mentioned in the slack channel you can use some other dataset available to you

# %% [markdown]
# 1. Seaborn: Includes datasets like tips, iris, titanic, and diamonds.
# Example: sns.load_dataset('tips')
# 2. Scikit-learn: Offers various datasets such as iris, digits, wine, and breast_cancer.
# Example: from sklearn.datasets import load_iris

# %%
import seaborn as sns
iris_df=sns.load_dataset('iris')
print(iris_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data=iris_df,x='petal_length', y='petal_width', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# if you havnt done so already you can also install sklearn or scikit-learn

# %%
#use 

#!pip install scikit-learn

#or 

#!conda install scikit-learn

import sklearn

# %%
from sklearn.datasets import load_breast_cancer

# Load the dataset
data = load_breast_cancer()

# Convert to DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)

# Add the target column (optional, if you want to include the target)
df['target'] = data.target

# Display the first few rows
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# Have fun =)
